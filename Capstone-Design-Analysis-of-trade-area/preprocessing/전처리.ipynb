# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np 
import os
import pandas as pd

# %%
os.getcwd()
os.chdir('C://Users//Jaesung//Desktop//해오라기//합칠거')

# %%
data = pd.read_csv('배후지.csv',engine ='python')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18398 entries, 0 to 18397
# Data columns (total 64 columns):
# 상권_코드              18398 non-null int64
# 서비스_업종_코드_명        18398 non-null object
# 평균_영업_개월_수         18398 non-null float64
# 당월_매출_금액           18398 non-null int64
# 월요일_매출_금액          18398 non-null int64
# 화요일_매출_금액          18398 non-null int64
# 수요일_매출_금액          18398 non-null int64
# 목요일_매출_금액          18398 non-null int64
# 금요일_매출_금액          18398 non-null int64
# 토요일_매출_금액          18398 non-null int64
# 일요일_매출_금액          18398 non-null int64
# 시간대_00~06_매출_금액    18398 non-null int64
# 시간대_06~11_매출_금액    18398 non-null int64
# 시간대_11~14_매출_금액    18398 non-null int64
# 시간대_14~17_매출_금액    18398 non-null int64
# 시간대_17~21_매출_금액    18398 non-null int64
# 시간대_21~24_매출_금액    18398 non-null int64
# 남성_매출_금액           18398 non-null int64
# 여성_매출_금액           18398 non-null int64
# 연령대_10_매출_금액       18398 non-null int64
# 연령대_20_매출_금액       18398 non-null int64
# ...

# %%
data.describe()
# Out:
#               상권_코드    평균_영업_개월_수      당월_매출_금액     월요일_매출_금액     화요일_매출_금액  \
# count  18398.000000  18398.000000  1.839800e+04  1.839800e+04  1.839800e+04
# mean     870.658822     51.154980  9.037544e+08  1.360507e+08  1.140087e+08
# std      504.493942     36.111789  1.561162e+09  2.404162e+08  2.025456e+08
# min        1.000000      1.000000  3.433500e+04 -7.592920e+05  0.000000e+00
# 25%      433.000000     34.693540  2.185373e+08  3.124028e+07  2.640700e+07
# 50%      869.000000     46.600000  4.240928e+08  6.274087e+07  5.301308e+07
# 75%     1311.000000     61.736842  8.976653e+08  1.363229e+08  1.151745e+08
# max     1744.000000   2023.090909  3.997321e+10  5.937944e+09  5.574434e+09
#
#           수요일_매출_금액     목요일_매출_금액     금요일_매출_금액     토요일_매출_금액     일요일_매출_금액  \
# count  1.839800e+04  1.839800e+04  1.839800e+04  1.839800e+04  1.839800e+04
# mean   1.191965e+08  1.198950e+08  1.332943e+08  1.406059e+08  1.407034e+08
# ...

# %%
data.head()
# Out:
#    상권_코드 서비스_업종_코드_명  평균_영업_개월_수    당월_매출_금액  월요일_매출_금액  화요일_매출_금액  수요일_매출_금액  \
# 0   1744         편의점   62.431818  1405271083  222010412  177766111  182535315
# 1   1744      호프간이주점   34.951282   785530821   91628787   91376796   90621493
# 2   1744        커피음료   22.636986   667956174   80405449   71331617   81477376
# 3   1744         제과점   41.309524   472753407   50135194   53750854   60241920
# 4   1744         치킨집   67.227273   358430949   47632332   36185141   39599027
#
#    목요일_매출_금액  금요일_매출_금액  토요일_매출_금액     ...      총_상주인구_수  청년층_유동인구_수.1  \
# 0  179214043  192084018  211213051     ...         38897          5817
# 1  106459912  114839003  147543382     ...         38897          5817
# 2   72728701   93825614  137108626     ...         38897          5817
# 3   59212064   68380650   86315597     ...         38897          5817
# 4   40735067   58703271   65655860     ...         38897          5817
#
# ...

# %%
data['청소년층_매출금액']=data['연령대_10_매출_금액']
data['청년층_매출금액']=data.apply(lambda row: row['연령대_20_매출_금액'] + row['연령대_30_매출_금액'], axis=1)
data['중년층_매출금액']=data.apply(lambda row: row['연령대_40_매출_금액'] + row['연령대_50_매출_금액'], axis=1)
data['장년층_매출금액']=data['연령대_60_이상_매출_금액']

# %%
data = data[['상권_코드', '서비스_업종_코드_명', '평균_영업_개월_수', '당월_매출_금액', '월요일_매출_금액',
       '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액',
       '일요일_매출_금액', '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
       '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
       '여성_매출_금액', '청소년층_매출금액', '청년층_매출금액','중년층_매출금액', '장년층_매출금액', '점포수', '집객시설_수',
       '관공서_수', '은행_수', '종합병원_수', '일반_병원_수', '약국_수', '유치원_수', '초등학교_수',
       '중학교_수', '고등학교_수', '대학교_수', '백화점_수', '슈퍼마켓_수', '극장_수', '숙박_시설_수',
       '버스_터미널_수', '지하철_역_수', '버스_정거장_수', '과밀_지수_구간_코드', '활성도_지표_구간_코드',
       '성장성_지표_구간_코드', '안정성_지표_구간_코드', '상권_코드_명', '총_유동인구_수', '청소년층_유동인구_수',
       '청년층_유동인구_수', '중년층_유동인구_수', '장년층_유동인구_수', '총_상주인구_수', '청년층_유동인구_수.1',
       '청년층_상주인구_수', '중년층_상주인구_수', '장년층_상주인구_수', '총_직장인구_수', '청소년층_직장인구_수',
       '청년층_직장인구_수', '중년층_직장인구_수', '장년층_직장인구_수', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
       '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액']]
data.head()
# Out:
#    상권_코드 서비스_업종_코드_명  평균_영업_개월_수    당월_매출_금액  월요일_매출_금액  화요일_매출_금액  수요일_매출_금액  \
# 0   1744         편의점   62.431818  1405271083  222010412  177766111  182535315
# 1   1744      호프간이주점   34.951282   785530821   91628787   91376796   90621493
# 2   1744        커피음료   22.636986   667956174   80405449   71331617   81477376
# 3   1744         제과점   41.309524   472753407   50135194   53750854   60241920
# 4   1744         치킨집   67.227273   358430949   47632332   36185141   39599027
#
#    목요일_매출_금액  금요일_매출_금액  토요일_매출_금액       ...         청소년층_직장인구_수  청년층_직장인구_수  \
# 0  179214043  192084018  211213051       ...                   1          73
# 1  106459912  114839003  147543382       ...                   1          73
# 2   72728701   93825614  137108626       ...                   1          73
# 3   59212064   68380650   86315597       ...                   1          73
# 4   40735067   58703271   65655860       ...                   1          73
#
# ...

# %%
data.columns
# Out:
# Index(['상권_코드', '서비스_업종_코드_명', '평균_영업_개월_수', '당월_매출_금액', '월요일_매출_금액',
#        '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액',
#        '일요일_매출_금액', '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '청소년층_매출금액', '청년층_매출금액', '중년층_매출금액', '장년층_매출금액', '점포수',
#        '집객시설_수', '관공서_수', '은행_수', '종합병원_수', '일반_병원_수', '약국_수', '유치원_수',
#        '초등학교_수', '중학교_수', '고등학교_수', '대학교_수', '백화점_수', '슈퍼마켓_수', '극장_수',
#        '숙박_시설_수', '버스_터미널_수', '지하철_역_수', '버스_정거장_수', '과밀_지수_구간_코드',
#        '활성도_지표_구간_코드', '성장성_지표_구간_코드', '안정성_지표_구간_코드', '상권_코드_명', '총_유동인구_수',
#        '청소년층_유동인구_수', '청년층_유동인구_수', '중년층_유동인구_수', '장년층_유동인구_수', '총_상주인구_수',
#        '청년층_유동인구_수.1', '청년층_상주인구_수', '중년층_상주인구_수', '장년층_상주인구_수', '총_직장인구_수',
#        '청소년층_직장인구_수', '청년층_직장인구_수', '중년층_직장인구_수', '장년층_직장인구_수', '연령대_10_매출_금액',
#        '연령대_20_매출_금액', '연령대_30_매출_금액', '연령대_40_매출_금액', '연령대_50_매출_금액',
# ...

# %%
data.drop('연령대_10_매출_금액', axis =1, inplace=True)
data.drop('연령대_20_매출_금액', axis =1, inplace=True)
data.drop('연령대_30_매출_금액', axis =1, inplace=True)
data.drop('연령대_40_매출_금액', axis =1, inplace=True)
data.drop('연령대_50_매출_금액', axis =1, inplace=True)
data.drop('연령대_60_이상_매출_금액', axis =1, inplace=True)

# %%
data.head()
# Out:
#    상권_코드 서비스_업종_코드_명  평균_영업_개월_수    당월_매출_금액  월요일_매출_금액  화요일_매출_금액  수요일_매출_금액  \
# 0   1744         편의점   62.431818  1405271083  222010412  177766111  182535315
# 1   1744      호프간이주점   34.951282   785530821   91628787   91376796   90621493
# 2   1744        커피음료   22.636986   667956174   80405449   71331617   81477376
# 3   1744         제과점   41.309524   472753407   50135194   53750854   60241920
# 4   1744         치킨집   67.227273   358430949   47632332   36185141   39599027
#
#    목요일_매출_금액  금요일_매출_금액  토요일_매출_금액     ...      총_상주인구_수  청년층_유동인구_수.1  \
# 0  179214043  192084018  211213051     ...         38897          5817
# 1  106459912  114839003  147543382     ...         38897          5817
# 2   72728701   93825614  137108626     ...         38897          5817
# 3   59212064   68380650   86315597     ...         38897          5817
# 4   40735067   58703271   65655860     ...         38897          5817
#
# ...

# %%
numeric_features = data.dtypes[data.dtypes != "object"].index
numeric_features
# Out:
# Index(['상권_코드', '평균_영업_개월_수', '당월_매출_금액', '월요일_매출_금액', '화요일_매출_금액',
#        '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액', '일요일_매출_금액',
#        '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '청소년층_매출금액', '청년층_매출금액', '중년층_매출금액', '장년층_매출금액', '점포수',
#        '집객시설_수', '관공서_수', '은행_수', '종합병원_수', '일반_병원_수', '약국_수', '유치원_수',
#        '초등학교_수', '중학교_수', '고등학교_수', '대학교_수', '백화점_수', '슈퍼마켓_수', '극장_수',
#        '숙박_시설_수', '버스_터미널_수', '지하철_역_수', '버스_정거장_수', '과밀_지수_구간_코드',
#        '활성도_지표_구간_코드', '성장성_지표_구간_코드', '안정성_지표_구간_코드', '총_유동인구_수',
#        '청소년층_유동인구_수', '청년층_유동인구_수', '중년층_유동인구_수', '장년층_유동인구_수', '총_상주인구_수',
#        '청년층_유동인구_수.1', '청년층_상주인구_수', '중년층_상주인구_수', '장년층_상주인구_수', '총_직장인구_수',
#        '청소년층_직장인구_수', '청년층_직장인구_수', '중년층_직장인구_수', '장년층_직장인구_수'],
#       dtype='object')

# %% [markdown]
# ### feature scaling

# %%
#from sklearn.preprocessing import MinMaxScaler

#scaler = MinMaxScaler() 
#scaled_values = scaler.fit_transform(data[numeric_features])

# %%
#scaled_values

# %%
#data.loc[:,numeric_features] = scaled_values

# %%
#data.head()

# %%
#data.describe()

# %% [markdown]
# ### Get dummy val for categorial values

# %%
data.drop("상권_코드_명", axis = 1, inplace = True)

# %%
data['상권_코드'] = data['상권_코드'].astype(str)

# %%
data.head()
# Out:
#   상권_코드 서비스_업종_코드_명  평균_영업_개월_수    당월_매출_금액  월요일_매출_금액  화요일_매출_금액  수요일_매출_금액  \
# 0  1744         편의점   62.431818  1405271083  222010412  177766111  182535315
# 1  1744      호프간이주점   34.951282   785530821   91628787   91376796   90621493
# 2  1744        커피음료   22.636986   667956174   80405449   71331617   81477376
# 3  1744         제과점   41.309524   472753407   50135194   53750854   60241920
# 4  1744         치킨집   67.227273   358430949   47632332   36185141   39599027
#
#    목요일_매출_금액  금요일_매출_금액  토요일_매출_금액     ...      총_상주인구_수  청년층_유동인구_수.1  \
# 0  179214043  192084018  211213051     ...         38897          5817
# 1  106459912  114839003  147543382     ...         38897          5817
# 2   72728701   93825614  137108626     ...         38897          5817
# 3   59212064   68380650   86315597     ...         38897          5817
# 4   40735067   58703271   65655860     ...         38897          5817
#
#    청년층_상주인구_수  중년층_상주인구_수  장년층_상주인구_수  총_직장인구_수  청소년층_직장인구_수  청년층_직장인구_수  \
# ...

# %%
data.shape
# Out:
# (18398, 61)

# %%
# process columns, apply LabelEncoder to categorical features
#=for c in cols:
#    lbl = LabelEncoder() 
#    lbl.fit(list(data[c].values)) 
#    data[c] = lbl.transform(list(data[c].values))

# shape        
#data.shape

# %%
data.head()
# Out:
#   상권_코드 서비스_업종_코드_명  평균_영업_개월_수    당월_매출_금액  월요일_매출_금액  화요일_매출_금액  수요일_매출_금액  \
# 0  1744         편의점   62.431818  1405271083  222010412  177766111  182535315
# 1  1744      호프간이주점   34.951282   785530821   91628787   91376796   90621493
# 2  1744        커피음료   22.636986   667956174   80405449   71331617   81477376
# 3  1744         제과점   41.309524   472753407   50135194   53750854   60241920
# 4  1744         치킨집   67.227273   358430949   47632332   36185141   39599027
#
#    목요일_매출_금액  금요일_매출_금액  토요일_매출_금액     ...      총_상주인구_수  청년층_유동인구_수.1  \
# 0  179214043  192084018  211213051     ...         38897          5817
# 1  106459912  114839003  147543382     ...         38897          5817
# 2   72728701   93825614  137108626     ...         38897          5817
# 3   59212064   68380650   86315597     ...         38897          5817
# 4   40735067   58703271   65655860     ...         38897          5817
#
#    청년층_상주인구_수  중년층_상주인구_수  장년층_상주인구_수  총_직장인구_수  청소년층_직장인구_수  청년층_직장인구_수  \
# ...

# %%
a = data['서비스_업종_코드_명']

# %% [markdown]
# ## 아래꺼 진행한다음 dummy 생성할 것 (과밀지수구간 binning - kmeans)

# %%
data.drop('서비스_업종_코드_명', axis =1, inplace=True)

# %%
data['서비스_업종_코드_명'] = a

# %%
data.head()
# Out:
#   상권_코드  평균_영업_개월_수    당월_매출_금액  월요일_매출_금액  화요일_매출_금액  수요일_매출_금액  목요일_매출_금액  \
# 0  1744   62.431818  1405271083  222010412  177766111  182535315  179214043
# 1  1744   34.951282   785530821   91628787   91376796   90621493  106459912
# 2  1744   22.636986   667956174   80405449   71331617   81477376   72728701
# 3  1744   41.309524   472753407   50135194   53750854   60241920   59212064
# 4  1744   67.227273   358430949   47632332   36185141   39599027   40735067
#
#    금요일_매출_금액  토요일_매출_금액  일요일_매출_금액     ...       청년층_상주인구_수  중년층_상주인구_수  \
# 0  192084018  211213051  240448133     ...            13275       12100
# 1  114839003  147543382  143061448     ...            13275       12100
# 2   93825614  137108626  131078791     ...            13275       12100
# 3   68380650   86315597   94717128     ...            13275       12100
# 4   58703271   65655860   69920251     ...            13275       12100
#
#    장년층_상주인구_수  총_직장인구_수  청소년층_직장인구_수  청년층_직장인구_수  중년층_직장인구_수  장년층_직장인구_수  \
# ...

# %%
data = pd.get_dummies(data, columns=['서비스_업종_코드_명'])

# %%
print(data.shape)
# Out:
# (18398, 72)

# %%
data.head()
# Out:
#   상권_코드  평균_영업_개월_수    당월_매출_금액  월요일_매출_금액  화요일_매출_금액  수요일_매출_금액  목요일_매출_금액  \
# 0  1744   62.431818  1405271083  222010412  177766111  182535315  179214043
# 1  1744   34.951282   785530821   91628787   91376796   90621493  106459912
# 2  1744   22.636986   667956174   80405449   71331617   81477376   72728701
# 3  1744   41.309524   472753407   50135194   53750854   60241920   59212064
# 4  1744   67.227273   358430949   47632332   36185141   39599027   40735067
#
#    금요일_매출_금액  토요일_매출_금액  일요일_매출_금액         ...          서비스_업종_코드_명_양식집  \
# 0  192084018  211213051  240448133         ...                        0
# 1  114839003  147543382  143061448         ...                        0
# 2   93825614  137108626  131078791         ...                        0
# 3   68380650   86315597   94717128         ...                        0
# 4   58703271   65655860   69920251         ...                        0
#
#    서비스_업종_코드_명_일식집  서비스_업종_코드_명_제과점  서비스_업종_코드_명_중국집  서비스_업종_코드_명_치킨집  \
# ...

# %% [markdown]
# ## 과밀 지수 구간 코드 binning

# %%
data["과밀_지수_구간_코드"].value_counts()
# Out:
# 0    6375
# 2    5682
# 3    5660
# 4     441
# 1     240
# Name: 과밀_지수_구간_코드, dtype: int64

# %%
train_test_data = [data] # train과 test set 합침

# %%
for dataset in train_test_data:
    dataset.loc[(dataset["과밀_지수_구간_코드"]==0),'과밀_지수_구간_코드_new'] = 0,
    dataset.loc[(dataset["과밀_지수_구간_코드"]==1) | (dataset["과밀_지수_구간_코드"]==2), '과밀_지수_구간_코드_new'] = 1,
    dataset.loc[(dataset["과밀_지수_구간_코드"]==3) | (dataset["과밀_지수_구간_코드"]==4), '과밀_지수_구간_코드_new'] = 2

# %%
data["과밀_지수_구간_코드"] = data["과밀_지수_구간_코드_new"]

# %%
data.drop('과밀_지수_구간_코드_new', axis =1, inplace=True)

# %% [markdown]
# # K means clustering

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
data['서비스_업종_코드_명'] = le.fit_transform(data['서비스_업종_코드_명'])

# %%
data.head()
# Out:
#   상권_코드  서비스_업종_코드_명  평균_영업_개월_수    당월_매출_금액  월요일_매출_금액  화요일_매출_금액  수요일_매출_금액  \
# 0  1744            8   62.431818  1405271083  222010412  177766111  182535315
# 1  1744           10   34.951282   785530821   91628787   91376796   90621493
# 2  1744            6   22.636986   667956174   80405449   71331617   81477376
# 3  1744            3   41.309524   472753407   50135194   53750854   60241920
# 4  1744            5   67.227273   358430949   47632332   36185141   39599027
#
#    목요일_매출_금액  금요일_매출_금액  토요일_매출_금액     ...      총_상주인구_수  청년층_유동인구_수.1  \
# 0  179214043  192084018  211213051     ...         38897          5817
# 1  106459912  114839003  147543382     ...         38897          5817
# 2   72728701   93825614  137108626     ...         38897          5817
# 3   59212064   68380650   86315597     ...         38897          5817
# 4   40735067   58703271   65655860     ...         38897          5817
#
# ...

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot  as plt
import seaborn as sns


# create model and prediction
model = KMeans(n_clusters=4,algorithm='auto')
model.fit(data)
predict = pd.DataFrame(model.predict(data))
predict.columns=['predict']

# %%
# concatenate labels to df as a new column
data = pd.concat([data,predict],axis=1)

# %%
ks = range(1,10)
inertias = []

for k in ks:
    model = KMeans(n_clusters=k)
    model.fit(data)
    inertias.append(model.inertia_)

# Plot ks vs inertias
plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %%
data.head()
# Out:
#   상권_코드  서비스_업종_코드_명  평균_영업_개월_수    당월_매출_금액  월요일_매출_금액  화요일_매출_금액  수요일_매출_금액  \
# 0  1744            8   62.431818  1405271083  222010412  177766111  182535315
# 1  1744           10   34.951282   785530821   91628787   91376796   90621493
# 2  1744            6   22.636986   667956174   80405449   71331617   81477376
# 3  1744            3   41.309524   472753407   50135194   53750854   60241920
# 4  1744            5   67.227273   358430949   47632332   36185141   39599027
#
#    목요일_매출_금액  금요일_매출_금액  토요일_매출_금액   ...     청년층_유동인구_수.1  청년층_상주인구_수  \
# 0  179214043  192084018  211213051   ...             5817       13275
# 1  106459912  114839003  147543382   ...             5817       13275
# 2   72728701   93825614  137108626   ...             5817       13275
# 3   59212064   68380650   86315597   ...             5817       13275
# 4   40735067   58703271   65655860   ...             5817       13275
#
#    중년층_상주인구_수  장년층_상주인구_수  총_직장인구_수  청소년층_직장인구_수  청년층_직장인구_수  중년층_직장인구_수  \
# ...

# %%
data["cluster"] = data["predict"]

# %%
data.drop('predict', axis =1, inplace=True)

# %%
#feature selection하지 않은 전체 data set
#data.to_csv('전처리완료1.csv',index=False,encoding='ms949')

# %% [markdown]
# ### 가서 dummy val 실행하고 오기 (위)

# %% [markdown]
# ## decision tree / feature selection

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18398 entries, 0 to 18397
# Data columns (total 72 columns):
# 상권_코드                 18398 non-null object
# 평균_영업_개월_수            18398 non-null float64
# 당월_매출_금액              18398 non-null int64
# 월요일_매출_금액             18398 non-null int64
# 화요일_매출_금액             18398 non-null int64
# 수요일_매출_금액             18398 non-null int64
# 목요일_매출_금액             18398 non-null int64
# 금요일_매출_금액             18398 non-null int64
# 토요일_매출_금액             18398 non-null int64
# 일요일_매출_금액             18398 non-null int64
# 시간대_00~06_매출_금액       18398 non-null int64
# 시간대_06~11_매출_금액       18398 non-null int64
# 시간대_11~14_매출_금액       18398 non-null int64
# 시간대_14~17_매출_금액       18398 non-null int64
# 시간대_17~21_매출_금액       18398 non-null int64
# 시간대_21~24_매출_금액       18398 non-null int64
# 남성_매출_금액              18398 non-null int64
# 여성_매출_금액              18398 non-null int64
# 청소년층_매출금액             18398 non-null int64
# ...

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
X = data[data.columns[data.columns!='과밀_지수_구간_코드']]
Y = data[data.columns[data.columns=='과밀_지수_구간_코드']]

# %%
X.columns
# Out:
# Index(['상권_코드', '평균_영업_개월_수', '당월_매출_금액', '월요일_매출_금액', '화요일_매출_금액',
#        '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액', '일요일_매출_금액',
#        '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '청소년층_매출금액', '청년층_매출금액', '중년층_매출금액', '장년층_매출금액', '점포수',
#        '집객시설_수', '관공서_수', '은행_수', '종합병원_수', '일반_병원_수', '약국_수', '유치원_수',
#        '초등학교_수', '중학교_수', '고등학교_수', '대학교_수', '백화점_수', '슈퍼마켓_수', '극장_수',
#        '숙박_시설_수', '버스_터미널_수', '지하철_역_수', '버스_정거장_수', '활성도_지표_구간_코드',
#        '성장성_지표_구간_코드', '안정성_지표_구간_코드', '총_유동인구_수', '청소년층_유동인구_수', '청년층_유동인구_수',
#        '중년층_유동인구_수', '장년층_유동인구_수', '총_상주인구_수', '청년층_유동인구_수.1', '청년층_상주인구_수',
#        '중년층_상주인구_수', '장년층_상주인구_수', '총_직장인구_수', '청소년층_직장인구_수', '청년층_직장인구_수',
#        '중년층_직장인구_수', '장년층_직장인구_수', '서비스_업종_코드_명_분식집', '서비스_업종_코드_명_양식집',
#        '서비스_업종_코드_명_일식집', '서비스_업종_코드_명_제과점', '서비스_업종_코드_명_중국집',
# ...

# %%
Y.columns
# Out:
# Index(['과밀_지수_구간_코드'], dtype='object')

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree1 = DecisionTreeClassifier(
    criterion='entropy', max_depth=1, random_state=0).fit(X, Y)

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel

# %%
X.shape
# Out:
# (18398, 71)

# %%
clf = ExtraTreesClassifier(n_estimators=50, random_state=40)
clf = clf.fit(X, Y)
clf.feature_importances_
# Out:
# C:\Users\Jaesung\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# array([0.01180023, 0.01258373, 0.01144318, 0.01139017, 0.01248126,
#        0.01255698, 0.01135824, 0.01137436, 0.01101355, 0.01135447,
#        0.01257616, 0.01268627, 0.01282609, 0.01249798, 0.01333612,
#        0.01381177, 0.01226941, 0.01136483, 0.01187724, 0.01162247,
#        0.013923  , 0.01260252, 0.01516999, 0.01118283, 0.01125665,
#        0.01141002, 0.00720898, 0.01063436, 0.01149711, 0.01105282,
#        0.01088768, 0.0109176 , 0.01019406, 0.00732284, 0.00143623,
#        0.01046083, 0.00911798, 0.011447  , 0.01126513, 0.00981773,
#        0.01119517, 0.08835509, 0.02908801, 0.05671626, 0.01239132,
#        0.01240871, 0.01292605, 0.01129299, 0.01201593, 0.0115348 ,
#        0.01230395, 0.01177209, 0.01190593, 0.01161354, 0.01399524,
# ...

# %%
model = SelectFromModel(clf, prefit=True)
X_new = model.transform(X)
X_new.shape
# Out:
# (18398, 9)

# %%
model.get_support()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True,  True,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False,  True, False, False, False,
#        False,  True,  True,  True, False, False, False, False])

# %%
#pd.DataFrame(X.columns,clf.feature_importances_).rank(axis=0,ascending=1)
rank = pd.DataFrame(X.columns,clf.feature_importances_).sort_index(axis=0 ,ascending=False)
rank
# Out:
#                            0
# 0.088355        활성도_지표_구간_코드
# 0.056720    서비스_업종_코드_명_커피음료
# 0.056716        안정성_지표_구간_코드
# 0.029088        성장성_지표_구간_코드
# 0.021906     서비스_업종_코드_명_치킨집
# 0.021549  서비스_업종_코드_명_패스트푸드점
# 0.020851     서비스_업종_코드_명_분식집
# 0.015170                 점포수
# 0.014431          중년층_직장인구_수
# 0.013995            총_직장인구_수
# 0.013923            중년층_매출금액
# 0.013812     시간대_21~24_매출_금액
# 0.013336     시간대_17~21_매출_금액
# 0.013079          청년층_직장인구_수
# 0.012926          청년층_유동인구_수
# 0.012826     시간대_11~14_매출_금액
# 0.012741          장년층_직장인구_수
# 0.012686     시간대_06~11_매출_금액
# 0.012603            장년층_매출금액
# 0.012584          평균_영업_개월_수
# 0.012576     시간대_00~06_매출_금액
# 0.012557           수요일_매출_금액
# 0.012498     시간대_14~17_매출_금액
# 0.012481           화요일_매출_금액
# 0.012409         청소년층_유동인구_수
# 0.012391            총_유동인구_수
# 0.012304        청년층_유동인구_수.1
# 0.012269            남성_매출_금액
# 0.012016          장년층_유동인구_수
# 0.011906          중년층_상주인구_수
# ...                      ...
# ...

# %% [markdown]
# ### 결과를 바탕으로 feature selection  - 원하시는 feature를 temp에 담으시면 됩니다

# %%
#select할 피쳐를 담아주시면 됩니다.
temp = data[['안정성_지표_구간_코드', '서비스_업종_코드_명_커피음료', '성장성_지표_구간_코드', 
             '서비스_업종_코드_명_치킨집', '서비스_업종_코드_명_패스트푸드점', '서비스_업종_코드_명_분식집', 'cluster','점포수','중년층_직장인구_수','총_직장인구_수']]



temp.head()
# Out:
#    안정성_지표_구간_코드  서비스_업종_코드_명_커피음료  성장성_지표_구간_코드  서비스_업종_코드_명_치킨집  \
# 0             1                 0             2                0
# 1             3                 0             3                0
# 2             0                 1             2                0
# 3             3                 0             3                0
# 4             0                 0             3                1
#
#    서비스_업종_코드_명_패스트푸드점  서비스_업종_코드_명_분식집  cluster  점포수  중년층_직장인구_수  총_직장인구_수
# 0                   0                0        1   44          84       169
# 1                   0                0        0   65          84       169
# 2                   0                0        0   73          84       169
# 3                   0                0        0   28          84       169
# 4                   0                0        0   22          84       169

# %%
temp['과밀_지수_구간_코드'] = data['과밀_지수_구간_코드']
# Out:
# C:\Users\Jaesung\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## save csv

# %%
temp.to_csv('전처리완료.csv',index=False,encoding='ms949')

# %% [markdown]
# ### case 1 ###
# 활성도_지표_구간_코드<br>
# 서비스_업종_코드_명_커피음료<br>
# 안정성_지표_구간_코드<br>
# 시간대_21~24_매출_금액<br>
# 중년층_매출금액<br>
# 점포수<br>
# 과밀_지수_구간_코드<br><br>
# feature: 7<br>
# XGB F-Score: 0.66<br>

# %% [markdown]
# #### case 2
#
# 활성도_지표_구간_코드<br>
# 서비스_업종_코드_명_커피음료<br>
# 안정성_지표_구간_코드<br>
# 성장성_지표_구간_코드<br>
# 점포수<br>
# 중년층_직장인구_수<br>
# 총_직장인구_수<br>
# 총_상주인구_수<br>
# 총_유동인구_수<br>
# 중년층_매출금액<br>
# 시간대_21~24_매출_금액<br>
# 시간대_17~21_매출_금액<br>
# 청년층_직장인구_수<br>
# 청년층_유동인구_수<br>
# 평균_영업_개월_수<br>
# cluster<br>
#
# feature: 16<br>
# XGB F-Score: 0.71<br>
# SVM F-Score: 0.34

# %% [markdown]
# #### case 3
#
# 활성도_지표_구간_코드<br>
# 서비스_업종_코드_명_커피음료<br>
# 안정성_지표_구간_코드<br>
# 성장성_지표_구간_코드<br>
# 점포수<br>
# 중년층_직장인구_수<br>
# 총_직장인구_수<br>
# 총_상주인구_수<br>
# 총_유동인구_수<br>
# 중년층_매출금액<br>
# 시간대_21~24_매출_금액<br>
# 시간대_17~21_매출_금액<br>
# 청년층_직장인구_수<br>
# 청년층_유동인구_수<br>
# 평균_영업_개월_수<br>
# <br>
#
# feature: 15<br>
# XGB F-Score: 0.701<br>

# %% [markdown]
# #### case 4
#
# 활성도_지표_구간_코드<br>
# 서비스_업종_코드_명_커피음료<br>
# 안정성_지표_구간_코드<br>
# 성장성_지표_구간_코드<br>
# 점포수<br>
# 중년층_직장인구_수<br>
# 총_직장인구_수<br>
# 남성_매출_금액<br>
# 청년층_직장인구_수<br>
# 중년층_상주인구_수<br>
# 총_상주인구_수<br>
# 시간대_11~14_매출_금액<br>
# 시간대_17~21_매출_금액<br>
# 과밀_지수_구간_코드<br>
# <br>
# feature: 14<br>
# XGB F-Score: 0.701<br>
# SVM F-Score: 0.341<br>

# %% [markdown]
# ## 하나씩 뜯어보기 - 추후 진행

# %% [markdown]
# #### 직장인구 범위 축소

# %%
temp.describe()
# Out:
#        활성도_지표_구간_코드  서비스_업종_코드_명_커피음료  안정성_지표_구간_코드  시간대_21~24_매출_금액  \
# count  18398.000000      18398.000000  18398.000000     1.839800e+04
# mean       1.790303          0.091043      1.762474     1.813483e+08
# std        1.267740          0.287677      1.032441     3.353207e+08
# min        0.000000          0.000000      0.000000     0.000000e+00
# 25%        0.000000          0.000000      1.000000     2.765813e+07
# 50%        2.000000          0.000000      2.000000     6.984047e+07
# 75%        3.000000          0.000000      2.000000     1.823600e+08
# max        4.000000          1.000000      4.000000     4.985064e+09
#
#            중년층_매출금액           점포수   과밀_지수_구간_코드
# count  1.839800e+04  18398.000000  18398.000000
# mean   2.696205e+08     44.042342      0.985107
# std    4.299770e+08     61.969679      0.823366
# min    0.000000e+00      1.000000      0.000000
# 25%    7.384687e+07     14.000000      0.000000
# 50%    1.347658e+08     24.000000      1.000000
# ...

# %% [markdown]
# 점포수
# 중년층_직장인구_수
# 총_직장인구_수
# 총_상주인구_수
# 총_유동인구_수
# 중년층_매출금액
# 시간대_21~24_매출_금액
# 시간대_17~21_매출_금액
# 청년층_직장인구_수
# 청년층_유동인구_수
# 평균_영업_개월_수

# %%
import seaborn as sns

# %%
#check saleprice(target value)
sns.distplot(temp['시간대_21~24_매출_금액']);

# %%
#중년층 직장인구 범위 축소 
temp["시간대_21~24_매출_금액"] = temp["시간대_21~24_매출_금액"].where(temp["시간대_21~24_매출_금액"] <3.923600e+08 , 3.923600e+08)
# Out:
# C:\Users\Jaesung\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sns.distplot(temp['시간대_21~24_매출_금액']);

# %%
sns.distplot(temp['중년층_매출금액']);

# %%
#중년층 직장인구 범위 축소 
temp["중년층_매출금액"] = temp["중년층_매출금액"].where(temp["중년층_매출금액"] <5.275206e+09 , 5.275206e+09)
# Out:
# C:\Users\Jaesung\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sns.distplot(temp['중년층_매출금액']);

# %%
temp.describe()
# Out:
#        활성도_지표_구간_코드  서비스_업종_코드_명_커피음료  안정성_지표_구간_코드  시간대_21~24_매출_금액  \
# count  18398.000000      18398.000000  18398.000000     1.839800e+04
# mean       1.790303          0.091043      1.762474     1.245790e+08
# std        1.267740          0.287677      1.032441     1.272583e+08
# min        0.000000          0.000000      0.000000     0.000000e+00
# 25%        0.000000          0.000000      1.000000     2.765813e+07
# 50%        2.000000          0.000000      2.000000     6.984047e+07
# 75%        3.000000          0.000000      2.000000     1.823600e+08
# max        4.000000          1.000000      4.000000     3.923600e+08
#
#            중년층_매출금액           점포수   과밀_지수_구간_코드
# count  1.839800e+04  18398.000000  18398.000000
# mean   2.692040e+08     44.042342      0.985107
# std    4.236041e+08     61.969679      0.823366
# min    0.000000e+00      1.000000      0.000000
# 25%    7.384687e+07     14.000000      0.000000
# 50%    1.347658e+08     24.000000      1.000000
# ...

# %%
#from pandas.tools.plotting import scatter_matrix # For older versions of Pandas
# from pandas.plotting import scatter_matrix

#attributes = ['과밀_지수_구간_코드','활성도_지표_구간_코드', '안정성_지표_구간_코드', '서비스_업종_코드_명_커피음료', 
#             '성장성_지표_구간_코드', '서비스_업종_코드_명_분식집', '서비스_업종_코드_명_패스트푸드점', '서비스_업종_코드_명_치킨집', 'cluster', '중년층_직장인구_수']
#scatter_matrix(temp[attributes], figsize=(12, 8))
#plt.show()
